# %%
def check_check():
    for d in range(1,100):
        for c in range(0,1,0.01):
            total=float(d+c)
            target=(total*2)-0.01
            
            actual=
            
            if d < 10:
                d=('0'+(str(d)))
            else:
                d=str(d)
            c = str(c).split('.')[1]
            
            
            if actual==target:
                return total
                break
            
            
            
        if (float(d+"."+c)*2)-0.01 == float(c+"."+d):
            return float(d+"."+c)
            break
        else:
            
    
    start=float(d+"."+c)
    end=float(c+"."+d)
    end_2=(start*2)-0.01
    
    print (start, end, end_2)
    
check_check('05','10')
# Out:
# 5.1 10.05 10.19
