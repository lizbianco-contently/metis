# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score, roc_curve, auc
from sklearn.naive_bayes import GaussianNB 
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier 
import statsmodels.api as sm    #import statsmodels for the stats models
from sklearn.linear_model import LogisticRegression 
import numpy as np
from pandas_confusion import ConfusionMatrix, BinaryConfusionMatrix, Backend

# %%
df = pd.read_csv('OnlineNewsPopularity.csv')#read in csv
df.rename(columns=lambda x: x.strip(), inplace=True)#get rid of weird spacing
df = df.set_index('url')#set index as Url (unpredicative)
df = df.drop(['timedelta'], axis=1)#drop timedelta (unpredictive)
FullFeatureSet, shares  = df.drop(['shares'], axis=1), df.shares #seperates features and label

# %%
shares.hist()
shares.describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: shares, dtype: float64

# %%
df['roundedshares'] = np.around(shares, decimals=-2)

# %%
print(roundedshares.mode())
roundedshares.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5f567e14b51c> in <module>()
# ----> 1 print(roundedshares.mode())
#       2 roundedshares.describe()
#
# NameError: name 'roundedshares' is not defined

# %%
urls=df[df['roundedshares'] > 10000].index.tolist()   
#for i in df:
#    if i['shares'] > 100000:
nonviral = df.drop(urls)
#nonviralfeatures, nonviralshares = nonviral.drop(['shares'], axis=1), nonviral.shares

# %%
nonviral.roundedshares.hist( bins=200)

# %%
print(nonviral.roundedshares.mode())
print(nonviral.roundedshares.describe())
print(df.roundedshares.mode())
print(df.roundedshares.describe())
# Out:
# 0    900
# dtype: int64
# count    37459.000000
# mean      2029.071785
# std       1771.680126
# min          0.000000
# 25%        900.000000
# 50%       1400.000000
# 75%       2400.000000
# max      10000.000000
# Name: roundedshares, dtype: float64
# 0    900
# dtype: int64
# count     39644.000000
# mean       3395.663909
# std       11626.902468
# min           0.000000
# 25%         900.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name: roundedshares, dtype: float64

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(FullFeatureSet, binaryshares, test_size=0.30, random_state=4444)

# %%
Shares.hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-80e024c45f62> in <module>()
# ----> 1 Shares.hist()
#
# NameError: name 'Shares' is not defined

# %%
binaryshares = []
for row in df['shares']:
    if row >= 1400:
        binaryshares.append(True)
    else:
        binaryshares.append(False)
df['binaryshares']= binaryshares
binaryshares = df['binaryshares']

# %%
kneighbordict = {}
Xtrain, Xtest, Ytrain, Ytest = train_test_split(FullFeatureSet, binaryshares, test_size=0.30, random_state=4444)
for i in range(1, 31):
    neigh = KNN(n_neighbors=i)
    neigh.fit(Xtrain, Ytrain)
    Ypredict = neigh.predict(Xtest)
    score = accuracy_score(Ytest, Ypredict)
    kneighbordict[i]=score
maxK = (max(kneighbordict, key=kneighbordict.get))
maxaccuracy = (max)

# %%
kneighbordict[maxK]

# %%
x = []
y = []
for i in kneighbordict.values():
    y.append(i)
for i in kneighbordict.keys():
    x.append(i)
plt.scatter(x, y)
plt.scatter(19, 0.58718681688246177, c='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-fe77c720488f> in <module>()
#       1 x = []
#       2 y = []
# ----> 3 for i in kneighbordict.values():
#       4     y.append(i)
#       5 for i in kneighbordict.keys():
#
# NameError: name 'kneighbordict' is not defined

# %%
def modelaccuracy(alg, x, y):
    Xtrain, Xtest, ytrain, ytest = train_test_split(x, y, test_size=0.30, random_state=4444)
    model = alg
    model = model.fit(Xtrain, ytrain)
    ypredict = model.predict(Xtest)
    accuracy = accuracy_score(ytest, ypredict)
    print('Accuracy: ' + str(accuracy))
    print(classification_report(ytest, ypredict))
#     cm = confusion_matrix(np.array(ytest), np.array(ypredict))
#     plot_confusion_matrix(cm)
#     cm = BinaryConfusionMatrix(ytest, ypredict)
#     cm.plot()
#     print('Normalized')
#     cm.plot(normalized=True)


    cm = confusion_matrix(ytest, ypredict)
    np.set_printoptions(precision=2)
    print('Confusion matrix, without normalization')
    print(cm)
    plt.figure()
    plot_confusion_matrix(cm)
    # Normalize the confusion matrix by row (i.e by the number of samples
    # in each class)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    print('Normalized confusion matrix')
    print(cm_normalized)
    plt.figure()
    plot_confusion_matrix(cm_normalized, title='Normalized confusion matrix')
    
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues):
    target_names = [True, False]
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(target_names))
    plt.xticks(tick_marks, target_names, rotation=45)
    plt.yticks(tick_marks, target_names)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

#     labels = ['business', 'health']
# cm = confusion_matrix(y_test, pred, labels)
# print(cm)
# fig = plt.figure()
# ax = fig.add_subplot(111)
# cax = ax.matshow(cm)
# pl.title('Confusion matrix of the classifier')
# fig.colorbar(cax)
# ax.set_xticklabels([''] + labels)
# ax.set_yticklabels([''] + labels)
# pl.xlabel('Predicted')
# pl.ylabel('True')
# pl.show()

# %%
modelaccuracy(KNN(n_neighbors=19), FullFeatureSet, binaryshares)
# Out:
# Accuracy: 0.587186816882
#              precision    recall  f1-score   support
#
#       False       0.56      0.54      0.55      5544
#        True       0.61      0.63      0.62      6350
#
# avg / total       0.59      0.59      0.59     11894
#
# Confusion matrix, without normalization
# [[2987 2557]
#  [2353 3997]]
# Normalized confusion matrix
# [[ 0.54  0.46]
#  [ 0.37  0.63]]

# %%
print ('Model: KNN')
modelaccuracy(KNeighborsClassifier(n_neighbors=19), FullFeatureSet, binaryshares)
print('\n')
print ('Model: Logistic Regression')
modelaccuracy(LogisticRegression(), FullFeatureSet, binaryshares)
print('\n')
print ('Model: Gaussian NB')
modelaccuracy(GaussianNB(), FullFeatureSet, binaryshares) 
print('\n')
# print ('Model: SVC')
# modelaccuracy(SVC(), X_train, X_test, y_train, y_test)
print('\n')
print ('Model: Decision Tree')
modelaccuracy(DecisionTreeClassifier(),FullFeatureSet, binaryshares)
print('\n')
print ('Model: Random Forest')
modelaccuracy(RandomForestClassifier(), FullFeatureSet, binaryshares)
# Out:
# Model: KNN
# Accuracy: 0.587186816882
#              precision    recall  f1-score   support
#
#       False       0.56      0.54      0.55      5544
#        True       0.61      0.63      0.62      6350
#
# avg / total       0.59      0.59      0.59     11894
#
# Confusion matrix, without normalization
# [[2987 2557]
#  [2353 3997]]
# Normalized confusion matrix
# [[ 0.54  0.46]
#  [ 0.37  0.63]]
#
#
# Model: Logistic Regression
# Accuracy: 0.602909029763
#              precision    recall  f1-score   support
#
#       False       0.58      0.52      0.55      5544
#        True       0.62      0.68      0.64      6350
#
# avg / total       0.60      0.60      0.60     11894
#
# Confusion matrix, without normalization
# [[2884 2660]
#  [2063 4287]]
# Normalized confusion matrix
# [[ 0.52  0.48]
#  [ 0.32  0.68]]
#
#
# Model: Gaussian NB
# Accuracy: 0.505633092315
#              precision    recall  f1-score   support
#
#       False       0.48      0.93      0.64      5544
#        True       0.69      0.13      0.22      6350
#
# avg / total       0.60      0.51      0.42     11894
#
# Confusion matrix, without normalization
# [[5170  374]
#  [5506  844]]
# Normalized confusion matrix
# [[ 0.93  0.07]
#  [ 0.87  0.13]]
#
#
#
#
# Model: Decision Tree
# Accuracy: 0.580376660501
#              precision    recall  f1-score   support
#
#       False       0.55      0.55      0.55      5544
#        True       0.61      0.60      0.61      6350
#
# avg / total       0.58      0.58      0.58     11894
#
# Confusion matrix, without normalization
# [[3068 2476]
#  [2515 3835]]
# Normalized confusion matrix
# [[ 0.55  0.45]
#  [ 0.4   0.6 ]]
#
#
# Model: Random Forest
# Accuracy: 0.625693627039
#              precision    recall  f1-score   support
#
#       False       0.59      0.65      0.62      5544
#        True       0.67      0.60      0.63      6350
#
# avg / total       0.63      0.63      0.63     11894
#
# Confusion matrix, without normalization
# [[3631 1913]
#  [2539 3811]]
# Normalized confusion matrix
# [[ 0.65  0.35]
#  [ 0.4   0.6 ]]

# %%
print ('Model: Random Forest')
modelaccuracy(RandomForestClassifier(n_estimators=250, max_features=6), FullFeatureSet, binaryshares)
# Out:
# Model: Random Forest
# Accuracy: 0.665629729275
#              precision    recall  f1-score   support
#
#       False       0.66      0.59      0.62      5544
#        True       0.67      0.73      0.70      6350
#
# avg / total       0.66      0.67      0.66     11894
#
# Confusion matrix, without normalization
# [[3284 2260]
#  [1717 4633]]
# Normalized confusion matrix
# [[ 0.59  0.41]
#  [ 0.27  0.73]]

# %%
limitedfeatureset =df[['LDA_02', 'kw_min_avg', 'kw_avg_avg', 'LDA_01', 'LDA_00', 'kw_max_avg', 'LDA_03', 'kw_avg_max', 'LDA_04', 'num_hrefs', 'self_reference_min_shares']]

# %%
print ('Model: KNN')
modelaccuracy(KNeighborsClassifier(n_neighbors=19), limitedfeatureset, binaryshares)
print('\n')
print ('Model: Logistic Regression')
modelaccuracy(LogisticRegression(), limitedfeatureset, binaryshares)
print('\n')
print ('Model: Gaussian NB')
modelaccuracy(GaussianNB(), limitedfeatureset, binaryshares) 
print('\n')
# print ('Model: SVC')
# modelaccuracy(SVC(), X_train, X_test, y_train, y_test)
print('\n')
print ('Model: Decision Tree')
modelaccuracy(DecisionTreeClassifier(),limitedfeatureset, binaryshares)
print('\n')
print ('Model: Random Forest')
modelaccuracy(RandomForestClassifier(), limitedfeatureset, binaryshares)
# Out:
# Model: KNN
# Accuracy: 0.587270892887
#              precision    recall  f1-score   support
#
#       False       0.56      0.54      0.55      5544
#        True       0.61      0.63      0.62      6350
#
# avg / total       0.59      0.59      0.59     11894
#
# Confusion matrix, without normalization
# [[2974 2570]
#  [2339 4011]]
# Normalized confusion matrix
# [[ 0.54  0.46]
#  [ 0.37  0.63]]
#
#
# Model: Logistic Regression
# Accuracy: 0.5517908189
#              precision    recall  f1-score   support
#
#       False       0.54      0.25      0.35      5544
#        True       0.55      0.81      0.66      6350
#
# avg / total       0.55      0.55      0.51     11894
#
# Confusion matrix, without normalization
# [[1413 4131]
#  [1200 5150]]
# Normalized confusion matrix
# [[ 0.25  0.75]
#  [ 0.19  0.81]]
#
#
# Model: Gaussian NB
# Accuracy: 0.542794686397
#              precision    recall  f1-score   support
#
#       False       0.51      0.83      0.63      5544
#        True       0.67      0.29      0.40      6350
#
# avg / total       0.59      0.54      0.51     11894
#
# Confusion matrix, without normalization
# [[4626  918]
#  [4520 1830]]
# Normalized confusion matrix
# [[ 0.83  0.17]
#  [ 0.71  0.29]]
#
#
#
#
# Model: Decision Tree
# Accuracy: 0.565158903649
#              precision    recall  f1-score   support
#
#       False       0.53      0.54      0.54      5544
#        True       0.59      0.59      0.59      6350
#
# avg / total       0.57      0.57      0.57     11894
#
# Confusion matrix, without normalization
# [[2986 2558]
#  [2614 3736]]
# Normalized confusion matrix
# [[ 0.54  0.46]
#  [ 0.41  0.59]]
#
#
# Model: Random Forest
# Accuracy: 0.605263157895
#              precision    recall  f1-score   support
#
#       False       0.57      0.63      0.60      5544
#        True       0.64      0.58      0.61      6350
#
# avg / total       0.61      0.61      0.61     11894
#
# Confusion matrix, without normalization
# [[3504 2040]
#  [2655 3695]]
# Normalized confusion matrix
# [[ 0.63  0.37]
#  [ 0.42  0.58]]

# %%
# # Recursive Feature Elimination

# from sklearn.feature_selection import RFE
# # create a base classifier used to evaluate a subset of attributes
# model = LogisticRegression()
# # create the RFE model and select 3 attributes
# rfe = RFE(model, 3)
# rfe = rfe.fit(FullFeatureSet, binaryshares)
# # summarize the selection of the attributes
# print(rfe.support_)
# print(rfe.ranking_)

# %%
#linear regression with logshares (linelog)
#logshares = np.log10(Shares)
#linelogXtrain, linelogXtest, linelogYtrain, linelogYtest = train_test_split(FullFeatureSet, logshares, test_size=0.30, random_state=4444)
#linelogmodel = sm.OLS(linelogYtrain, linelogXtrain).fit()
#test = linelogmodel.predict(linelogXtest)
#test.summary()

# %%
from sklearn.grid_search import GridSearchCV, RandomizedSearchCV
from scipy.stats import randint as sp_randint
from time import time

# %%
clf = RandomForestClassifier(n_estimators = 20)
X = FullFeatureSet
y = binaryshares

def report(grid_scores, n_top=3):
    top_scores = sorted(grid_scores, key=itemgetter(1), reverse=True)[:n_top]
    for i, score in enumerate(top_scores):
        print("Model with rank: {0}".format(i + 1))
        print("Mean validation score: {0:.3f} (std: {1:.3f})".format(score.mean_validation_score, np.std(score.cv_validation_scores)))
        prin("Paramaters: {0}".format(score.parameters))
        print("")

param_dist = {"max_depth": [3, None],
              "max_features": sp_randint(1, 11),
              "min_samples_split": sp_randint(1, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

n_iter_search = 20
random_search = RandomizedSearchCV(clf, param_distributions=param_dist,
                                   n_iter=n_iter_search)

start = time()
random_search.fit(X, y)
print("RandomizedSearchCV took %.2f seconds for %d candidates"
      " parameter settings." % ((time() - start), n_iter_search))
report(random_search.grid_scores_)

param_grid = {"max_depth": [3, None],
              "max_features": [1, 3, 10],
              "min_samples_split": [1, 3, 10],
              "min_samples_leaf": [1, 3, 10],
              "bootstrap": [True, False],
              "criterion": ["gini", "entropy"]}

grid_search = GridSearchCV(clf, param_grid=param_grid)
start = time()
grid_search.fit(X, y)



print("GridSearchCV took %.2f seconds for %d candidate parameter settings."
      % (time() - start, len(grid_search.grid_scores_)))
report(grid_search.grid_scores_)

# %%
import

# %%
Xtrain, Xtest, Ytrain, Ytest = train_test_split(FullFeatureSet, binaryshares, test_size=0.30, random_state=4444)
gbm = xgb.XGBCLassifier(n_estimators = 200).fit(Xtrain, ytrain)
ypredict = gbm.predict(Xtest)
accuracy = accuracy_score(ytest, ypredict)
print('Accuracy: ' + str(accuracy))
print(classification_report(ytest, ypredict))
