# %%
topic_titles.append("violent extreamism")

# %%
topics[1]
# Out:
# (1,
#  '0.002*ballast + 0.002*ballast water + 0.001*covered major rule + 0.001*water discharge + 0.001*ballast water discharge + 0.001*incidental + 0.001*discharge standard + 0.001*policy modernization + 0.001*energy policy modernization + 0.001*water discharge standard + 0.001*policy modernization act + 0.001*january percent + 0.001*incidental normal + 0.001*incidental normal operation + 0.001*normal operation + 0.001*operation vessel + 0.001*december january + 0.001*fishing recreational shooting + 0.001*recreational shooting + 0.001*normal operation vessel')

# %%
topic_titles.append("ballast water, energy policy")

# %%
topics[2]
# Out:
# (2,
#  '0.007*currency currency + 0.006*currency currency currency + 0.004*proposed ms collins + 0.004*euro + 0.004*dollar dollar + 0.004*states dollar + 0.004*united states dollar + 0.004*kirk mr reed + 0.004*foreign equivalent + 0.004*collins mr kirk + 0.004*reed mr tester + 0.003*transportation housing + 0.003*urban development related + 0.003*transportation housing urban + 0.003*equivalent foreign + 0.003*foreign equivalent foreign + 0.003*equivalent foreign equivalent + 0.003*tester supra + 0.003*mr tester supra + 0.003*departments transportation')

# %%
topic_titles.append("currency")

# %%
topics[3]
# Out:
# (3,
#  '0.001*amtrak + 0.001*mcconnell mr thune + 0.001*motor carrier + 0.001*act administrator federal + 0.001*enactment federal + 0.001*date enactment federal + 0.001*employees health + 0.001*administration taken + 0.001*account purposes determining + 0.001*taken account purposes + 0.001*account purposes + 0.001*veterans administration + 0.001*exempt employees health + 0.001*determining employers + 0.001*mandate applies + 0.001*employer mandate applies + 0.001*administration taken account + 0.001*purposes determining employers + 0.001*tricare veterans + 0.001*tricare veterans administration')

# %%
topic_titles.append("amtrak, VA")

# %%
topics[4]
# Out:
# (4,
#  '0.005*lee mr flake + 0.005*xl + 0.005*keystone xl + 0.004*keystone xl pipeline + 0.004*xl pipeline + 0.004*hoeven mr barrasso + 0.004*portman mr alexander + 0.004*cassidy mr gardner + 0.004*murkowski mr hoeven + 0.004*risch mr lee + 0.004*gardner mr portman + 0.004*barrasso mr risch + 0.004*alexander mrs capito + 0.004*daines mr manchin + 0.004*manchin mr cassidy + 0.004*flake mr daines + 0.003*need schools + 0.003*communities risk + 0.003*ayotte mr graham + 0.003*approve keystone')

# %%
topic_titles.append("keystone")

# %%
topics[5]
# Out:
# (5,
#  '0.008*countering violent + 0.008*countering violent extremism + 0.007*mr shelby ms + 0.007*shelby ms + 0.005*shelby ms mikulski + 0.004*mikulski supra + 0.004*ms mikulski supra + 0.004*mikulski supra ordered + 0.003*proposed mr shelby + 0.003*appeared + 0.003*congressional record + 0.003*received senate + 0.003*appeared congressional + 0.003*senate appeared congressional + 0.003*appeared congressional record + 0.003*senate appeared + 0.003*received senate appeared + 0.002*high energy + 0.002*nominations received + 0.002*nominations received senate')

# %%
topic_titles.append('countering violent extreamism')

# %%
topics[6]
# Out:
# (6,
#  '0.005*counter violent + 0.003*special counsel + 0.003*federal entity + 0.003*aviation administration shall + 0.002*licensee + 0.001*aerospace + 0.001*automation + 0.001*construction prescribe + 0.001*construction prescribe military + 0.001*military construction prescribe + 0.001*traffic control tower + 0.001*control tower + 0.001*flint + 0.001*section omnibus + 0.001*passport + 0.001*allocated state + 0.001*improve cybersecurity + 0.001*material support + 0.001*amendments table + 0.001*information data')

# %%
topic_titles.append('military contracts')

# %%
topics[7]
# Out:
# (7,
#  '0.009*provided legislation + 0.009*total fiscal + 0.009*total fiscal years + 0.009*period total + 0.009*period total fiscal + 0.008*page line increase + 0.008*line increase + 0.008*increase page + 0.008*line increase page + 0.008*increase page line + 0.005*levels fiscal + 0.005*government fiscal + 0.005*government fiscal year + 0.005*budget united states + 0.005*budget united + 0.005*levels fiscal years + 0.005*forth appropriate + 0.005*forth appropriate budgetary + 0.005*res setting + 0.005*res setting forth')

# %%
topic_titles.append('budget')

# %%
topics[8]
# Out:
# (8,
#  '0.009*open skies + 0.008*skies treaty + 0.008*open skies treaty + 0.005*counter violent extremism + 0.004*mcconnell supra + 0.004*mr mcconnell supra + 0.003*freedom navigation + 0.003*mcconnell supra ordered + 0.003*sttr + 0.002*sonar + 0.002*selective + 0.002*selective service + 0.002*guantanamo + 0.002*burr mrs feinstein + 0.002*act ordered + 0.002*act ordered lie + 0.002*care act ordered + 0.002*exempt employees + 0.002*coverage tricare + 0.002*sensors')

# %%
topic_titles.append('open skies treaty')

# %%
topics[9]
# Out:
# (9,
#  '0.015*res supra + 0.015*resolution res supra + 0.013*res supra ordered + 0.003*noise + 0.002*res supra sa + 0.002*faa aviation + 0.002*general aviation + 0.001*aviation industry + 0.001*department ensure + 0.001*inventions + 0.001*leahy mr whitehouse + 0.001*feinstein ms collins + 0.001*recurrent + 0.001*tax exempt + 0.001*amendment concurrent resolution + 0.001*proposed amendment concurrent + 0.001*amendment concurrent + 0.001*geothermal + 0.001*exempt status + 0.001*conspired')

# %%
topic_titles.append('aviation industry')

# %%
topics[10]
# Out:
# (10,
#  '0.001*section homeland security + 0.001*section homeland + 0.001*federal chief information + 0.001*realignment + 0.001*government data + 0.001*partnerships violent extremism + 0.001*partnerships violent + 0.001*investigative leave + 0.000*data inventory + 0.000*enterprise data inventory + 0.000*enterprise data + 0.000*data assets + 0.000*components department + 0.000*congressional homeland + 0.000*inserting federal chief + 0.000*congressional homeland security + 0.000*security committees + 0.000*homeland security committees + 0.000*whistleblower + 0.000*data asset')

# %%
topic_titles.append('homeland security')

# %%
topics[11]
# Out:
# (11,
#  '0.014*mccain supra ordered + 0.004*aeronautical + 0.003*flight deck + 0.003*deck + 0.002*northern border + 0.002*federal flight + 0.002*federal flight deck + 0.002*alliances + 0.002*performance objectives + 0.001*manned + 0.001*airman + 0.001*visual + 0.001*pounds + 0.001*batteries + 0.001*threat analysis + 0.001*manned aircraft + 0.001*deck officers + 0.001*flight deck officers + 0.001*benefit cost + 0.001*liability protection')

# %%
topic_titles.append('aviation')

# %%
topics[12]
# Out:
# (12,
#  '0.001*ms murkowski supra + 0.001*murkowski supra + 0.001*murkowski supra ordered + 0.001*yakima + 0.001*basin + 0.001*irrigation + 0.001*murkowski provide modernization + 0.001*murkowski provide + 0.001*ms murkowski provide + 0.001*yakima river + 0.001*lighting + 0.001*river basin + 0.000*integrated plan + 0.000*electric utility + 0.000*energy savings + 0.000*yakama + 0.000*yakima river basin + 0.000*carbon fiber + 0.000*bureau reclamation + 0.000*fiber')

# %%
topic_titles.append('yakima river')

# %%
topics[13]
# Out:
# (13,
#  '0.007*air carrier + 0.005*oda + 0.003*student academic + 0.003*education act ensure + 0.003*student academic achievement + 0.002*section faa + 0.002*retired pay + 0.002*section faa modernization + 0.002*retiree + 0.002*model aircraft + 0.002*modernization reform + 0.002*modernization reform act + 0.002*faa modernization reform + 0.002*faa modernization + 0.002*qualified retiree + 0.002*reform act note + 0.002*services partnership + 0.002*investment services partnership + 0.002*investment services + 0.002*domestic terrorism')

# %%
topic_titles.append('education')

# %%
topics[14]
# Out:
# (14,
#  '0.010*joint task + 0.003*justice science + 0.003*science related + 0.003*justice science related + 0.003*departments commerce + 0.003*science related agencies + 0.003*commerce justice science + 0.003*departments commerce justice + 0.003*federal chief + 0.003*commerce justice + 0.002*striking administrator + 0.002*mcconnell mr thune + 0.002*transferee + 0.002*leave employee + 0.001*notice period + 0.001*marys + 0.001*st marys + 0.001*nics + 0.001*notice leave + 0.001*submit committee homeland')

# %%
topic_titles.append('unknown')

# %%
topics[15]
# Out:
# (15,
#  '0.003*administrative leave + 0.001*striking administrator inserting + 0.001*rocket + 0.001*contract award + 0.001*altitude + 0.001*iowa + 0.001*coordination administrator + 0.001*opioid addiction + 0.001*fda + 0.001*flight hours + 0.001*isis + 0.001*airline + 0.001*atlas + 0.001*arkansas + 0.001*authoritative + 0.001*paragraph striking administrator + 0.001*regarding effectiveness + 0.001*firefighting + 0.000*capacities + 0.000*scalia')

# %%
topic_titles.append('unknown')

# %%
topics[16]
# Out:
# (16,
#  '0.003*state educational + 0.002*state educational agency + 0.001*charter school + 0.001*charter schools + 0.001*principals + 0.001*learners + 0.001*school leaders + 0.001*early childhood + 0.001*instructional + 0.001*english learners + 0.001*academic achievement + 0.001*principals school + 0.001*principals school leaders + 0.001*child achieves + 0.001*teachers principals + 0.001*subgrant + 0.001*state academic + 0.001*subgrants + 0.001*childhood education + 0.001*early childhood education')

# %%
topic_titles.append("education")

# %%
topics[17]
# Out:
# (17,
#  '0.002*appropriations departments commerce + 0.002*ms mikulski making + 0.002*mikulski making + 0.002*mikulski making appropriations + 0.001*background check + 0.001*ammunition + 0.001*second amendment + 0.001*instant + 0.001*nics + 0.001*proposed ms collins + 0.000*transfer firearm + 0.000*shelby ms mikulski + 0.000*amendment rights + 0.000*second amendment rights + 0.000*following sec funds + 0.000*mcconnell mr shelby + 0.000*rights protection act + 0.000*incidents mass + 0.000*incidents mass violence + 0.000*safety second')

# %%
topic_titles.append("appropriations")

# %%
topics[18]
# Out:
# (18,
#  '0.006*unmanned aircraft + 0.003*aircraft systems + 0.003*unmanned aircraft systems + 0.002*economic freedom zone + 0.002*freedom zone + 0.001*administrator federal aviation + 0.001*revenue code permanently + 0.001*code permanently + 0.001*code permanently extend + 0.001*permanently extend increased + 0.001*increased expensing limitations + 0.001*increased expensing + 0.001*expensing limitations + 0.001*extend increased expensing + 0.001*extend increased + 0.001*expensing limitations purposes + 0.001*limitations purposes + 0.001*nelson supra + 0.001*limitations purposes ordered + 0.001*mr nelson supra')

# %%
topic_titles.append('drones')

# %%
topics[19]
# Out:
# (19,
#  '0.003*skies + 0.003*cyber threat + 0.002*cyber threat indicators + 0.002*threat indicators + 0.001*gambling + 0.001*cyber threat indicator + 0.001*threat indicator + 0.001*mrs murray supra + 0.001*murray supra + 0.001*murray supra ordered + 0.001*biodiesel + 0.001*problem gambling + 0.001*cybersecurity threats + 0.001*defense acquisition + 0.001*test evaluation + 0.001*cybersecurity threat + 0.001*military department + 0.001*member member + 0.000*defensive measures + 0.000*removal period')

# %%
topic_titles.append('cyber secureity')

# %%
topics =list( zip(topics, topic_titles))

# %%
topics
# Out:
# [(((0,
#     '0.009*extremism + 0.009*violent extremism + 0.007*joint task force + 0.004*chief information + 0.004*economic freedom + 0.004*information officer + 0.004*chief information officer + 0.002*closure realignment + 0.002*inserting federal + 0.002*joint duty + 0.002*sbir + 0.002*joint requirements + 0.001*human capital + 0.001*disinformation + 0.001*propaganda + 0.001*electronic government + 0.001*adverse action + 0.001*situational + 0.001*situational awareness + 0.001*department leadership'),
#    'violent extreamism'),
#   'violent extreamism'),
#  (((1,
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('jun20df.csv')

# %%
df.shape
# Out:
# (14860, 7)

# %%
df = df.drop('session', axis=1)

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#              date    speaker  \
# 0      2015-01-06  McCONNELL
# 1      2015-01-06     DURBIN
# 2      2015-01-06     DURBIN
# 3      2015-01-06     DURBIN
# 4      2015-01-06      HATCH
# 5      2015-01-06     MURPHY
# 6      2015-01-06     MURPHY
# 7      2015-01-06     MURPHY
# 8      2015-01-06     MURPHY
# 9      2015-01-06     MURPHY
# 10     2015-01-06     MURPHY
# 11     2015-01-06     MURPHY
# 12     2015-01-06     MURPHY
# 13     2015-01-06     MURPHY
# 14     2015-01-06     MURPHY
# 15     2015-01-06     MURPHY
# 16     2015-01-06     MURPHY
# 17     2015-01-06     MURPHY
# 18     2015-01-06     MURPHY
# 19     2015-01-06     MURPHY
# 20     2015-01-06     MURPHY
# 21     2015-01-06    COLLINS
# 22     2015-01-06    COLLINS
# 23     2015-01-06    COLLINS
# 24     2015-01-06    COLLINS
# 25     2015-01-06       KING
# 26     2015-01-06       KING
# 27     2015-01-06  McCONNELL
# 28     2015-01-06      UDALL
# 29     2015-01-06    MERKLEY
# ...           ...        ...
# ...

# %%
lda = df['lda']

# %%
len(lda_tuples)
# Out:
# 14860

# %%
lda_tuples[9]
# Out:
# [('5', '0.026162769219419377'),
#  ('8', '0.16492754977288659'),
#  ('13', '0.80108916177194522')]

# %%
lda_tuples = []
for i in lda:
    i = i.strip('[]').strip('()').split('), (')
    index_list = []
    for j in i:
        templist = j.split(', ')
        tup = (templist[0], templist[1])
        index_list.append(tup)
    lda_tuples.append(index_list)

# %%
assigned_topics = []
for i in lda_tuples:
    maxtopic = max(i, key=lambda x:x[1])
    value = float(maxtopic[1])
    if value > 0.2:
        assigned_topics.append(maxtopic[0])
    else:
        assigned_topics.append('NaN')

# %%
assigned_topics[:5]
# Out:
# ['13', '13', '16', '16', '13']

# %%
df['topics'] = assigned_topics

# %%
df
# Out:
#              date    speaker  \
# 0      2015-01-06  McCONNELL
# 1      2015-01-06     DURBIN
# 2      2015-01-06     DURBIN
# 3      2015-01-06     DURBIN
# 4      2015-01-06      HATCH
# 5      2015-01-06     MURPHY
# 6      2015-01-06     MURPHY
# 7      2015-01-06     MURPHY
# 8      2015-01-06     MURPHY
# 9      2015-01-06     MURPHY
# 10     2015-01-06     MURPHY
# 11     2015-01-06     MURPHY
# 12     2015-01-06     MURPHY
# 13     2015-01-06     MURPHY
# 14     2015-01-06     MURPHY
# 15     2015-01-06     MURPHY
# 16     2015-01-06     MURPHY
# 17     2015-01-06     MURPHY
# 18     2015-01-06     MURPHY
# 19     2015-01-06     MURPHY
# 20     2015-01-06     MURPHY
# 21     2015-01-06    COLLINS
# 22     2015-01-06    COLLINS
# 23     2015-01-06    COLLINS
# 24     2015-01-06    COLLINS
# 25     2015-01-06       KING
# 26     2015-01-06       KING
# 27     2015-01-06  McCONNELL
# 28     2015-01-06      UDALL
# 29     2015-01-06    MERKLEY
# ...           ...        ...
# ...

# %%
roster = pd.read_csv('roster114.csv')

# %%
names = roster.title

# %%
lastnames = []
for i in names:
    splitnames = i.split(' ')
    lastname = splitnames[-1].lower()
    if lastname == 'Jr.':
        lastnames.append(splitnames[-2].lower())
    else:
        
        lastnames.append(lastname)

# %%
lastnames
# Out:
# ['leahy',
#  'hatch',
#  'cochran',
#  'grassley',
#  'mcconnell',
#  'mikulski',
#  'shelby',
#  'mccain',
#  'reid',
#  'feinstein',
#  'boxer',
#  'murray',
#  'inhofe',
#  'wyden',
#  'roberts',
#  'durbin',
#  'reed',
#  'sessions',
#  'collins',
#  'enzi',
#  'schumer',
#  'crapo',
#  'nelson',
#  'carper',
#  'stabenow',
#  'cantwell',
#  'cornyn',
#  'murkowski',
#  'graham',
#  'alexander',
#  'burr',
#  'thune',
#  'isakson',
#  'vitter',
#  'menendez',
#  'cardin',
#  'sanders',
#  'brown',
#  'jr.',
#  'corker',
#  'mccaskill',
#  'klobuchar',
#  'whitehouse',
#  'tester',
#  'barrasso',
#  'wicker',
#  'udall',
#  'shaheen',
#  'warner',
#  'risch',
#  'merkley',
#  'bennet',
#  'gillibrand',
#  'franken',
#  'manchin',
#  'coons',
#  'kirk',
#  'coats',
#  'blunt',
#  'moran',
#  'portman',
#  'boozman',
#  'toomey',
#  'hoeven',
#  'rubio',
#  'johnson',
#  'paul',
#  'blumenthal',
#  'lee',
#  'ayotte',
#  'heller',
#  'schatz',
#  'scott',
#  'baldwin',
#  'flake',
# ...

# %%
roster['lastnames'] = lastnames
rosterparties = roster.party
rosterstates = roster.state

# %%
party = []
state = []
for i in df.speaker:
    try:
        index = lastnames.index(i.lower())
        party.append(rosterparties[index])
        state.append(rosterstates[index])
    except ValueError:
        party.append('not found')
        state.append('not found')

# %%
df['party']=party
df['state'] = state

# %%
df
# Out:
#              date    speaker  \
# 0      2015-01-06  McCONNELL
# 1      2015-01-06     DURBIN
# 2      2015-01-06     DURBIN
# 3      2015-01-06     DURBIN
# 4      2015-01-06      HATCH
# 5      2015-01-06     MURPHY
# 6      2015-01-06     MURPHY
# 7      2015-01-06     MURPHY
# 8      2015-01-06     MURPHY
# 9      2015-01-06     MURPHY
# 10     2015-01-06     MURPHY
# 11     2015-01-06     MURPHY
# 12     2015-01-06     MURPHY
# 13     2015-01-06     MURPHY
# 14     2015-01-06     MURPHY
# 15     2015-01-06     MURPHY
# 16     2015-01-06     MURPHY
# 17     2015-01-06     MURPHY
# 18     2015-01-06     MURPHY
# 19     2015-01-06     MURPHY
# 20     2015-01-06     MURPHY
# 21     2015-01-06    COLLINS
# 22     2015-01-06    COLLINS
# 23     2015-01-06    COLLINS
# 24     2015-01-06    COLLINS
# 25     2015-01-06       KING
# 26     2015-01-06       KING
# 27     2015-01-06  McCONNELL
# 28     2015-01-06      UDALL
# 29     2015-01-06    MERKLEY
# ...           ...        ...
# ...

# %%
topic_title = ['military defense',
 'unknown',
 'violent extreamism',
 'FAA and aircraft systems',
 'unknown',
 'budget',
 'firearms',
 'education',
 'join task forces',
 'Veterans benefits',
 'Veterans benefits',
 'unknown',
 'cyber security',
 'unknown',
 'water',
 'opioid epidemic',
 'drones',
 'biodiesel',
 'keystone pipeline']

# %%
topic_name = []

# %%
for i in df.topics:
    try:
        i = int(i)
        topic = topic_title[i]
        topic_name.append(topic)
    except ValueError:
        topic_name.append('unknown')

# %%
topic_name[:20]
# Out:
# ['unknown',
#  'unknown',
#  'drones',
#  'drones',
#  'unknown',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense',
#  'military defense']

# %%
df['topic']=topic_name

# %%
df = df.drop('text', axis=1)
df = df.drop('lda', axis=1 )
df = df.drop('topics', axis=1)

# %%
df
# Out:
#              date    speaker  \
# 0      2015-01-06  McCONNELL
# 1      2015-01-06     DURBIN
# 2      2015-01-06     DURBIN
# 3      2015-01-06     DURBIN
# 4      2015-01-06      HATCH
# 5      2015-01-06     MURPHY
# 6      2015-01-06     MURPHY
# 7      2015-01-06     MURPHY
# 8      2015-01-06     MURPHY
# 9      2015-01-06     MURPHY
# 10     2015-01-06     MURPHY
# 11     2015-01-06     MURPHY
# 12     2015-01-06     MURPHY
# 13     2015-01-06     MURPHY
# 14     2015-01-06     MURPHY
# 15     2015-01-06     MURPHY
# 16     2015-01-06     MURPHY
# 17     2015-01-06     MURPHY
# 18     2015-01-06     MURPHY
# 19     2015-01-06     MURPHY
# 20     2015-01-06     MURPHY
# 21     2015-01-06    COLLINS
# 22     2015-01-06    COLLINS
# 23     2015-01-06    COLLINS
# 24     2015-01-06    COLLINS
# 25     2015-01-06       KING
# 26     2015-01-06       KING
# 27     2015-01-06  McCONNELL
# 28     2015-01-06      UDALL
# 29     2015-01-06    MERKLEY
# ...           ...        ...
# ...

# %% [markdown]
# #### topic_0 = []
# topic_1 = []
# topic_2 = []
# topic_3 = []
# topic_4 = []
# topic_5 = []
# topic_6 = []
# topic_7 = []
# topic_8 = []
# topic_9 = []
# topic_10 = []
# topic_11 = []
# topic_12 = []
# topic_13 = []
# topic_14 = []
# topic_15 =[]
# topic_16 = []
# topic_17 = []
# topic_18 = []
# topic_19 = []

# %%
def assign_topic_value(topic_tuples):
    for i in topic_tuples:
        for j in topics
        
        
        if i[0] == '0':
            topic_0.append(i[1])
        else:
            topic_0.append('0')
#             if i[0] == '1':
#                 topic_1.append(i[1])
#             else:
#                 topic_1.append('0')
#                 if i[0] == '2':
#                     topic_2.append(i[1])  
#                 else:
#                     topic_2.append('0')
#                     if i[0] == '3':
#                         topic_3.append(i[1]) 
#                     else:
#                         topic_3.append('0')
#                         if i[0] == '4':
#                             topic_4.append(i[1]) 
#                         else:
#                             topic_4.append('0')
#                             if i[0] == '5':
#                                 topic_5.append(i[1]) 
#                             else:
#                                 topic_5.append('0')
#                                 if i[0] == '6':
#                                     topic_6.append(i[1]) 
#                                 else:
#                                     topic_6.append('0')
#                                     if i[0] == '7':
#                                         topic_7.append(i[1]) 
#                                     else:
#                                         topic_7.append('0')
#                                         if i[0] == '8':
#                                             topic_8.append(i[1]) 
#                                         else:
#                                             topic_8.append('0')
#                                             if i[0] == '9':
#                                                  topic_9.append(i[1]) 
#                                             else:
#                                                 topic_9.append('0')
#                                                 if i[0] == '10':
#                                                      topic_10.append(i[1])
#                                                 else:
#                                                     topic_10.append('0')
#                                                     if i[0] == '11':
#                                                          topic_11.append(i[1])
#                                                     else:
#                                                         topic_11.append('0')
#                                                         if i[0] == '12':
#                                                              topic_12.append(i[1])
#                                                         else:
#                                                             topic_12.append('0')
#                                                             if i[0] == '13':
#                                                                  topic_13.append(i[1])
#                                                             else:
#                                                                 topic_13.append('0')
#                                                                 if i[0] == '14':
#                                                                      topic_14.append(i[1])
#                                                                 else:
#                                                                     topic_14.append('0')
#                                                                     if i[0] == '15':
#                                                                          topic_15.append(i[1])
#                                                                     else:
#                                                                         topic_15.append('0')
#                                                                         if i[0] == '16':
#                                                                              topic_16.append(i[1])
#                                                                         else:
#                                                                             topic_16.append('0')
#                                                                             if i[0] == '17':
#                                                                                  topic_17.append(i[1])
# Out:
# [[('1', '0.010350831850358238'),
#   ('5', '0.26831120957836835'),
#   ('6', '0.033742845587706627'),
#   ('7', '0.083095013700988193'),
#   ('9', '0.092660438559992245'),
#   ('12', '0.021213062782027722'),
#   ('13', '0.01718005944351457'),
#   ('15', '0.28330259214107073'),
#   ('16', '0.011021378656841864'),
#   ('17', '0.14418247940875958'),
#   ('18', '0.010371584087358341')],
#  [('0', '0.084655974421437269'),
#   ('5', '0.38867970293850784'),
#   ('6', '0.015375115787345048'),
#   ('9', '0.059380350659190353'),
#   ('15', '0.33405487745651119'),
#   ('17', '0.025402142107994304'),
#   ('19', '0.08034460416123447')],
#  [('3', '0.014523958214595506'),
#   ('5', '0.19056485535584386'),
#   ('6', '0.01151486625730758'),
#   ('11', '0.6484124697768362'),
#   ('15', '0.1309515923081358')],
#  [('3', '0.014526675729380821'),
#   ('5', '0.19056192068096969'),
#   ('6', '0.011514881146422486'),
#   ('11', '0.64841252366255187'),
#   ('15', '0.13095174069341672')],
# ...

# %%
test = test.strip('()')

# %%
splittest = test.split('), (')

# %%
testtuples = []
for i in splittest:
    j = i.split(', ')
    tup = (j[0], j[1])
    testtuples.append(tup)

# %%
print(testtuples)
# Out:
# [('5', '0.026162822561494381'), ('8', '0.16492754630907061'), ('13', '0.80108922369605795')]
